# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import explore

from wrangle import wrangle_telco, get_mall_data

# %%
train, validate, test = wrangle_telco()
train.head()
# Out:
#      customer_id  monthly_charges  tenure  total_charges
# 1171  6980-IMXXE            20.20      69        1412.65
# 736   4573-JKNAE            19.35      12         212.30
# 1485  8774-GSBUN            25.40      72        1797.10
# 1139  6770-UAYGJ            25.25      49        1211.65
# 689   4139-DETXS            64.45      72        4528.00

# %%
explore.plot_variable_pairs(train)

# %%
explore.months_to_years(train)
# Out:
#      customer_id  monthly_charges  tenure  total_charges  months_to_years  \
# 1171  6980-IMXXE            20.20      69        1412.65              6.0
# 736   4573-JKNAE            19.35      12         212.30              1.0
# 1485  8774-GSBUN            25.40      72        1797.10              6.0
# 1139  6770-UAYGJ            25.25      49        1211.65              4.0
# 689   4139-DETXS            64.45      72        4528.00              6.0
# ...          ...              ...     ...            ...              ...
# 441   2664-XJZNO           104.90      72        7559.55              6.0
# 98    0567-XRHCU            43.95      69        2960.10              6.0
# 886   5334-AFQJB            25.10      72        1789.90              6.0
# 322   2001-MCUUW           108.65      46        4903.20              4.0
# 1593  9418-RUKPH            19.95      38         756.40              3.0
#
#       is_tenured
# 1171        True
# 736         True
# 1485        True
# ...

# %%
explore.plot_categorical_and_continuous_vars(train , 'months_to_years', 'monthly_charges')
# Out:
# ('months_to_years', 'monthly_charges')

# %%
df = get_mall_data()
df.head()
# Out:
#    customer_id  gender  age  annual_income  spending_score
# 0            1    Male   19             15              39
# 1            2    Male   21             15              81
# 2            3  Female   20             16               6
# 3            4  Female   23             16              77
# 4            5  Female   31             17              40

# %%
explore.plot_variable_pairs(df)

# %%
explore.plot_categorical_and_continuous_vars(df , 'gender', 'spending_score')
# Out:
# ('gender', 'spending_score')
